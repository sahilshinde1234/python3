# %% [markdown]
# # Why data visualization?

# %% [markdown]
# Data visulaization is a quick, easy way to convey concept in a universal manner.

# %% [markdown]
# # What is Data Visualization

# %% [markdown]
# 1.Data Visualization is the graphical representaion of information and data
# 2.visual element like charts,graphs,and maps ,data visualization tools aaprovide an accessible way to see and understand trends,outliers and patterns in data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # What Is matplotlib

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Matplotlib Graph

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Linear Plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bar plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Stem Plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Step plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Hist Plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Box Plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Pie plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Fill_Between plot

# %% [markdown]
# ![image.png](attachment:image.png)
